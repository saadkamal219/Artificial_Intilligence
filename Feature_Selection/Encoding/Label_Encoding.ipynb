# %% [markdown]
# <a href="https://colab.research.google.com/github/saadkamal219/Artificial_Intilligence/blob/main/Label_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

filepath = '/content/drive/MyDrive/Machine Learning Dataset/customer.csv'

dataframe = pd.read_csv(filepath)

dataframe.sample(5)
# Out:
#     age  gender   review education purchased
# 7    60  Female     Poor    School       Yes
# 0    30  Female  Average    School        No
# 47   38  Female     Good        PG       Yes
# 24   16  Female  Average        PG       Yes
# 29   83  Female  Average        UG       Yes

# %% [markdown]
# #This data set have been through Ordinal Encoding and will be used for extended work as Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataframe['purchased'] = labelencoder.fit_transform(dataframe['purchased'])

# %%
dataframe.sample(5)
# Out:
#     age  gender   review education  purchased
# 5    31  Female  Average    School          1
# 8    65  Female  Average        UG          0
# 31   22  Female     Poor    School          1
# 14   15    Male     Poor        PG          1
# 37   94    Male  Average        PG          1
