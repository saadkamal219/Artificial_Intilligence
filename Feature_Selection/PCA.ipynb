# %% [markdown]
# <a href="https://colab.research.google.com/github/saadkamal219/Artificial_Intilligence/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

filepath = '/content/drive/MyDrive/Machine Learning Dataset/iris.csv'

dataframe = pd.read_csv(filepath)

dataframe.sample(5)
# Out:
#     sepallength  sepalwidth  petallength  petalwidth            class
# 25          5.0         3.0          1.6         0.2      Iris-setosa
# 82          5.8         2.7          3.9         1.2  Iris-versicolor
# 65          6.7         3.1          4.4         1.4  Iris-versicolor
# 50          7.0         3.2          4.7         1.4  Iris-versicolor
# 94          5.6         2.7          4.2         1.3  Iris-versicolor

# %%
x = dataframe.iloc[:,0:4]
y = dataframe.iloc[:,4:]

# %%
x_scaled = StandardScaler().fit_transform(x)

# %% [markdown]
# #**PCA**

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)
x_pca_df = pd.DataFrame(x_pca, columns = ['Col1', 'Col2'])
x_pca_df
# Out:
#          Col1      Col2
# 0   -2.264542  0.505704
# 1   -2.086426 -0.655405
# 2   -2.367950 -0.318477
# 3   -2.304197 -0.575368
# 4   -2.388777  0.674767
# ..        ...       ...
# 145  1.870522  0.382822
# 146  1.558492 -0.905314
# 147  1.520845  0.266795
# 148  1.376391  1.016362
# 149  0.959299 -0.022284
#
# [150 rows x 2 columns]

# %%
#alternative

# x_pca = PCA(n_components=2).fit_transform(x_scaled)
# x_pca_df = pd.DataFrame(x_pca, columns = ['Col1', 'col2'])
# x_pca_df

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_pca, y, train_size=0.7, random_state=1)

# %%
#model training
import warnings

warnings.filterwarnings('ignore')

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print("Accuracy score after PCA: ", (accuracy_score(y_test,y_pred))*100, "%")
# Out:
# Accuracy score after PCA:  88.88888888888889 %
